# %% [markdown]
# # Como reproducir un Video de YoutTube en Jupyter Notebook

# %% [markdown]
# > Aqui el codigo **fuente** para practicar, se debe buscar el **codigo** del Video en **YouTube**

# %%
from IPython.display import YouTubeVideo

#YouTubeVideo('WSbgixdC9g8', width=800, height=600)

YouTubeVideo('86Xz4e-LCuY', width=800, height=600)

# %% [markdown]
# ### https://qastack.mx/programming/32370281/how-to-embed-image-or-picture-in-jupyter-notebook-either-from-a-local-machine-o

# %% [markdown]
# ## Hay varias formas de publicar una imagen en los cuadernos Jupyter:

# %% [markdown]
# > a través de HTML:

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "http://my_site.com/my_picture.jpg")
# Out:
# <img src="http://my_site.com/my_picture.jpg"/>

# %%
#Conserva la capacidad de usar etiquetas HTML para cambiar el tamaño, etc.

Image(url= "http://my_site.com/my_picture.jpg", width=100, height=100)
# Out:
# <img src="http://my_site.com/my_picture.jpg" width="100" height="100"/>

# %% [markdown]
# ### Ejemplo de recoleccion y analisis dinamico de grandes cantidades de datos de Terremotos y Tsunamis desde 1901 a 2020
#
# > ¿Qué es un terremoto?
# Un **terremoto** es el movimiento brusco de la *Tierra* (con mayúsculas, ya que nos referimos al planeta), causado por la brusca liberación de energía acumulada durante un largo tiempo. ... terremotos ocurren alejados de los límites de estas placas.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('ilFEKSZQv5o', width=800, height=600)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('rd2jKGQJucE', width=800, height=600)

# %%
"\N{Sauropod}" * 10
# Out:
# '🦕🦕🦕🦕🦕🦕🦕🦕🦕🦕'

# %%
"\N{T-REx}" * 10
# Out:
# '🦖🦖🦖🦖🦖🦖🦖🦖🦖🦖'
